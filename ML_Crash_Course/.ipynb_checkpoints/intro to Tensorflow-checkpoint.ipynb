# 9963       2795.0      1267.0         2.2094              83.700
# 13452      2267.0       944.0         2.7727             235.600
# 7893        491.0       287.0         3.2222             319.400
# 4790        986.0       336.0         2.6901             235.600
# 653        1067.0       350.0         5.7416             243.400
# 2126       1793.0       622.0         2.5754             169.700
# 6831       1138.0       357.0         2.7125             150.000
# 8419        393.0       250.0         2.9167             461.100
# 6435       1215.0       431.0         5.0234             257.600
#
# [17000 rows x 9 columns]

# %%
cal_housing_dataframe.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean           207.300912
# std            115.983764
# min             14.999000
# 25%            119.400000
# 50%            180.400000
# 75%            265.000000
# max            500.001000

# %%
my_feature = cal_housing_dataframe[['total_rooms']]
feature_columns = [tf.feature_column.numeric_column("total_rooms")]
feature_columns
# Out:
# [_NumericColumn(key='total_rooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
targets = cal_housing_dataframe["median_house_value"]
targets
# Out:
# 15811    236.200
# 12377     92.500
# 15340    227.400
# 10958     94.200
# 491      195.900
# 7681     366.900
# 11276    125.200
# 12331    158.300
# 16934     92.800
# 2094     145.700
# 2507     175.400
# 1537     182.100
# 10745    222.900
# 2356     154.700
# 5956     129.700
# 8665     222.500
# 474      151.700
# 5003     218.900
# 15291    147.900
# 8223     500.001
# 5074     137.500
# 2864     129.200
# 826      185.500
# 12657    192.400
# 5302     336.000
# 8491     261.300
# 4952     352.200
# 14861    273.700
# 12514     72.500
# 3207     254.100
#           ...
# 16594    258.100
# 1860     500.001
# 7947     210.500
# 9786     106.200
# 9350     167.400
# 157       32.900
# 16474    324.700
# 4365     179.800
# 11219    263.100
# 11440    141.100
# 188      176.400
# 3305     156.900
# 7191     500.001
# 13734    411.200
# 13823    131.600
# 12372     74.800
# 14162    222.000
# 1849     214.600
# 2693     248.000
# 6247     187.500
# 14054    211.300
# 9963      83.700
# 13452    235.600
# 7893     319.400
# 4790     235.600
# 653      243.400
# 2126     169.700
# 6831     150.000
# 8419     461.100
# 6435     257.600
# Name: median_house_value, Length: 17000, dtype: float64

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.00001)
optimizer = tf.contrib.estimator.clip_gradients_by_norm(optimizer, 5.0)

linear_regressor = tf.estimator.LinearRegressor(
    feature_columns= feature_columns,
    optimizer = optimizer)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpnrkdgk60
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_task_type': 'worker', '_save_checkpoints_steps': None, '_tf_random_seed': None, '_master': '', '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa9b4bdfba8>, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_save_checkpoints_secs': 600, '_service': None, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': '/tmp/tmpnrkdgk60', '_task_id': 0}

# %%
def input_fn(features, targets, batch_size=1, shuffle=True, num_epochs=None):
    
    features = {key:np.array(value) for key,value in dict(features).items()}
    
    ds = tf.data.Dataset.from_tensor_slices((features, targets))
    ds = ds.batch(batch_size).repeat(num_epochs)
    
    if shuffle: 
        ds = ds.shuffle(buffer_size=10000)
        
    features, labels = ds.make_one_shot_iterator().get_next()
    return features, labels

# %%
_= linear_regressor.train(
    input_fn = lambda:input_fn(my_feature, targets),
    steps = 9000
)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tm
# INFO:tensorflow:global_step/sec: 816.437
# INFO:tensorflow:step = 8001, loss = 7078.171 (0.119 sec)
# INFO:tensorflow:global_step/sec: 883.666
# INFO:tensorflow:step = 8101, loss = 1254.3201 (0.114 sec)
# INFO:tensorflow:global_step/sec: 845.958
# INFO:tensorflow:step = 8201, loss = 5675.4795 (0.127 sec)
# INFO:tensorflow:global_step/sec: 852.16
# INFO:tensorflow:step = 8301, loss = 1278.1553 (0.108 sec)
# INFO:tensorflow:global_step/sec: 694.087
# INFO:tensorflow:step = 8401, loss = 3080.3635 (0.144 sec)
# INFO:tensorflow:global_step/sec: 932.041
# INFO:tensorflow:step = 8501, loss = 12613.192 (0.107 sec)
# INFO:tensorflow:global_step/sec: 735.307
# INFO:tensorflow:step = 8601, loss = 1117.9082 (0.137 sec)
# INFO:tensorflow:global_step/sec: 929.399
# INFO:tensorflow:step = 8701, loss = 45366.426 (0.110 sec)
# INFO:tensorflow:global_step/sec: 820.734
# INFO:tensorflow:step = 8801, loss = 16742.182 (0.119 sec)
# INFO:tensorflow:global_step/sec: 917.125
# INFO:tensorflow:step = 8901, loss = 821.4675 (0.116 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpnrkdgk60/model.ckpt.
# INFO:tensorflow:Loss for final step: 59870.516.

# %%
from sklearn.metrics import mean_squared_error

import math
prediction_input_fn = lambda: input_fn(my_feature, targets, num_epochs = 1, shuffle = False)
predictions = linear_regressor.predict(input_fn=prediction_input_fn)
predictions = np.array([item['predictions'][0] for item in predictions])

mean_squared_error = metrics.mean_squared_error(predictions, targets)
root_mean_squared_error = math.sqrt(mean_squared_error)

print("Mean Squared Error (on training data): %0.3f" % mean_squared_error)
print("Root Mean Squared Error (on training data): %0.3f" % root_mean_squared_error)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tmpnrkdgk60/model.ckpt-9000
# Mean Squared Error (on training data): 42792.088
# Root Mean Squared Error (on training data): 206.862

# %%
min_house_value = cal_housing_dataframe["median_house_value"].min()
max_house_value = cal_housing_dataframe["median_house_value"].max()

max_min_difference = max_house_value - min_house_value

print("Min. Median House Value: %0.3f" % min_house_value)
print("Max. Median House Value: %0.3f" % max_house_value)
print("Difference between Min. and Max.: %0.3f" % max_min_difference)
print("Root Mean Squared Error: %0.3f" % root_mean_squared_error)
# Out:
# Min. Median House Value: 14.999
# Max. Median House Value: 500.001
# Difference between Min. and Max.: 485.002
# Root Mean Squared Error: 206.862

# %%
calibration_data = pd.DataFrame()
calibration_data['prediction'] = pd.Series(predictions)
calibration_data['targets'] = pd.Series(targets)
calibration_data.describe()
# Out:
#          prediction       targets
# count  17000.000000  17000.000000
# mean     225.768478    207.300912
# std      186.166931    115.983764
# min        0.171004     14.999000
# 25%      124.854637    119.400000
# 50%      181.645462    180.400000
# 75%      269.116165    265.000000
# max     3239.810547    500.001000

# %%
sample = cal_housing_dataframe.sample(300)
sample
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 
#        population  households  median_income  median_house_value
# 16566       636.0       295.0         2.7222             161.200
# 13910       808.0       241.0         4.0125             161.400
# 13285      1799.0       734.0         2.2993              99.500
# 11867      1185.0       506.0         3.2243             107.900
# 15705       879.0       309.0         2.2222             195.100
# 8343        598.0       280.0         3.4698             265.400
# 3167       2817.0      1073.0         5.0629             232.600
# 1150       1315.0       321.0         1.9286              78.500
# 14591       568.0       225.0         2.9917             194.600
# 10980      2445.0       832.0         3.7611             123.100
# 13874       682.0       254.0         4.8611             240.000
# 9961       4638.0      1335.0         1.2716              69.400
# 9598       2030.0       522.0         1.5223              51.800
# 9623        879.0       257.0         2.5234              63.500
# 12183      1963.0       622.0         3.3125              96.800
# 7983       3738.0       880.0         3.1910             271.200
# 6537        980.0       319.0         3.3500             177.700
# 3357       4429.0      1299.0         4.7589             178.200
# 235        1274.0       688.0         3.7396             148.900
# 8139        498.0       216.0        10.9237             500.001
# 190        1046.0       367.0         1.7137             110.700
# 14854      2920.0       832.0         3.4360              94.800
# 7148       1254.0       395.0         7.0935             379.500
# 11640      3327.0       957.0         4.4871             137.900
# 2361        711.0       172.0         4.8214             143.400
# 8407       1229.0       663.0         3.5909             500.001
# 2586        572.0       174.0        13.0502             500.001
# 3553       1037.0       317.0         2.2132             138.500
# 5610        753.0       298.0         2.6591             183.800
# 1068       2303.0       486.0         2.5953              67.500
# ...           ...         ...            ...                 ...
# 15819       921.0       247.0         4.4464             215.400
# 16037      1705.0       608.0         4.9318             258.100
# 9728        617.0       222.0         3.0833             133.300
# 532        1456.0       449.0         4.3714             131.000
# 16275       795.0       297.0         4.3977             353.600
# 12296       260.0       128.0         2.9219             152.900
# 6339       1799.0       370.0         2.3750             128.000
# 13642      2186.0       772.0         3.1167             258.300
# 7248        714.0       295.0         2.8125             229.900
# 1926        436.0       168.0         3.1667             160.600
# 9927       1375.0       518.0         2.5737              76.900
# 7749       1008.0       415.0         5.8518             337.900
# 8965       1344.0       306.0         2.0921              61.400
# 11840      1363.0       519.0         4.0036             161.700
# 7431       1134.0       408.0         3.8250             235.400
# 1842        978.0       332.0         4.3542             156.900
# 9715       1205.0       389.0         1.8333              68.300
# 8505       1190.0       421.0        10.6796             500.001
# 13041      1985.0       917.0         2.9085             156.300
# 11472       730.0       242.0         4.9688             135.600
# 7078        578.0       204.0         5.7393             500.001
# 16644      1554.0       528.0         3.3531              90.800
# 921         818.0       307.0         3.4773             150.400
# 550        1864.0       664.0         4.3152             159.300
# 8668       1287.0       525.0         5.0605             311.000
# 11248       501.0       206.0         3.6477             113.400
# 8846       1392.0       451.0         5.4459             223.900
# 11909      1234.0       377.0         5.5427             162.100
# 9414       2467.0       600.0         2.3125              62.100
# 10633      1001.0       319.0         4.4628             134.400
#
# [300 rows x 9 columns]

# %%
x_0 = sample["total_rooms"].min()
x_1 = sample["total_rooms"].max()

# %%
weight = linear_regressor.get_variable_value('linear/linear_model/total_rooms/weights')[0]
bias = linear_regressor.get_variable_value('linear/linear_model/bias_weights')

# %%
y_0 = weight*x_0 + bias
y_1 = weight*x_1 + bias

# %%
plt.plot([x_0, x_1], [y_0, y_1], c='r')
plt.ylabel("median_house_value")
plt.xlabel("total_rooms")
plt.scatter(sample["total_rooms"], sample["median_house_value"])
plt.show()

# %%
def train_model(learning_rate, steps, batch_size, input_feature="total_rooms"):
  """Trains a linear regression model of one feature.
  
  Args:
    learning_rate: A `float`, the learning rate.
    steps: A non-zero `int`, the total number of training steps. A training step
      consists of a forward and backward pass using a single batch.
    batch_size: A non-zero `int`, the batch size.
    input_feature: A `string` specifying a column from `california_housing_dataframe`
      to use as input feature.
  """
  
  periods = 10
  steps_per_period = steps / periods

  my_feature = input_feature
  my_feature_data = cal_housing_dataframe[[my_feature]]
  my_label = "median_house_value"
  targets = cal_housing_dataframe[my_label]

  # Create feature columns.
  feature_columns = [tf.feature_column.numeric_column(my_feature)]
  
  # Create input functions.
  training_input_fn = lambda:input_fn(my_feature_data, targets, batch_size=batch_size)
  prediction_input_fn = lambda: input_fn(my_feature_data, targets, num_epochs=1, shuffle=False)
  
  # Create a linear regressor object.
  my_optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
  my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
  linear_regressor = tf.estimator.LinearRegressor(
      feature_columns=feature_columns,
      optimizer=my_optimizer
  )

  # Set up to plot the state of our model's line each period.
  plt.figure(figsize=(15, 6))
  plt.subplot(1, 2, 1)
  plt.title("Learned Line by Period")
  plt.ylabel(my_label)
  plt.xlabel(my_feature)
  sample = cal_housing_dataframe.sample(n=300)
  plt.scatter(sample[my_feature], sample[my_label])
  colors = [cm.coolwarm(x) for x in np.linspace(-1, 1, periods)]

  # Train the model, but do so inside a loop so that we can periodically assess
  # loss metrics.
  print("Training model...")
  print("RMSE (on training data):")
  root_mean_squared_errors = []
  for period in range (0, periods):
    # Train the model, starting from the prior state.
    linear_regressor.train(
        input_fn=training_input_fn,
        steps=steps_per_period
    )
    # Take a break and compute predictions.
    predictions = linear_regressor.predict(input_fn=prediction_input_fn)
    predictions = np.array([item['predictions'][0] for item in predictions])
    
    # Compute loss.
    root_mean_squared_error = math.sqrt(
        metrics.mean_squared_error(predictions, targets))
    # Occasionally print the current loss.
    print("  period %02d : %0.2f" % (period, root_mean_squared_error))
    # Add the loss metrics from this period to our list.
    root_mean_squared_errors.append(root_mean_squared_error)
    # Finally, track the weights and biases over time.
    # Apply some math to ensure that the data and line are plotted neatly.
    y_extents = np.array([0, sample[my_label].max()])
    
    weight = linear_regressor.get_variable_value('linear/linear_model/%s/weights' % input_feature)[0]
    bias = linear_regressor.get_variable_value('linear/linear_model/bias_weights')

    x_extents = (y_extents - bias) / weight
    x_extents = np.maximum(np.minimum(x_extents,
                                      sample[my_feature].max()),
                           sample[my_feature].min())
    y_extents = weight * x_extents + bias
    plt.plot(x_extents, y_extents, color=colors[period]) 
  print("Model training finished.")

  # Output a graph of loss metrics over periods.
  plt.subplot(1, 2, 2)
  plt.ylabel('RMSE')
  plt.xlabel('Periods')
  plt.title("Root Mean Squared Error vs. Periods")
  plt.tight_layout()
  plt.plot(root_mean_squared_errors)

  # Output a table with calibration data.
  calibration_data = pd.DataFrame()
  calibration_data["predictions"] = pd.Series(predictions)
  calibration_data["targets"] = pd.Series(targets)
  display.display(calibration_data.describe())

  print("Final RMSE (on training data): %0.2f" % root_mean_squared_error)

# %%
from IPython import display
train_model(
    learning_rate=0.00002,
    steps=600,
    batch_size=6
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpu2ktd0ep
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_task_type': 'worker', '_save_checkpoints_steps': None, '_tf_random_seed': None, '_master': '', '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa9adb2e9e8>, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_save_checkpoints_secs': 600, '_service': None, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': '/tmp/tmpu2ktd0ep', '_task_id': 0}
# Training model...
# RMSE (on training data):
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 1, loss = 466929.22
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 425902.88.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-60
#   period 00 : 216.60
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-60
# INFO:tensorflow:Saving checkpoints for 61 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 61, loss = 327377.7
# INFO:tensorflow:Saving checkpoints for 120 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 289648.44.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-120
#   period 01 : 198.26
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-120
# INFO:tensorflow:Saving checkpoints for 121 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 121, loss = 465447.56
# INFO:tensorflow:Saving checkpoints for 180 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 136953.1.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-180
#   period 02 : 184.18
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-180
# INFO:tensorflow:Saving checkpoints for 181 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 181, loss = 116485.65
# INFO:tensorflow:Saving checkpoints for 240 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 71517.69.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-240
#   period 03 : 173.77
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-240
# INFO:tensorflow:Saving checkpoints for 241 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 241, loss = 219568.28
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 96193.875.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-300
#   period 04 : 168.78
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-300
# INFO:tensorflow:Saving checkpoints for 301 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 301, loss = 92083.83
# INFO:tensorflow:Saving checkpoints for 360 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 182338.03.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-360
#   period 05 : 166.63
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-360
# INFO:tensorflow:Saving checkpoints for 361 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 361, loss = 286823.5
# INFO:tensorflow:Saving checkpoints for 420 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 46283.297.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-420
#   period 06 : 166.47
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-420
# INFO:tensorflow:Saving checkpoints for 421 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 421, loss = 72444.664
# INFO:tensorflow:Saving checkpoints for 480 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 162810.62.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-480
#   period 07 : 167.23
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-480
# INFO:tensorflow:Saving checkpoints for 481 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 481, loss = 169158.17
# INFO:tensorflow:Saving checkpoints for 540 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 250645.47.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-540
#   period 08 : 167.58
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-540
# INFO:tensorflow:Saving checkpoints for 541 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:step = 541, loss = 108065.664
# INFO:tensorflow:Saving checkpoints for 600 into /tmp/tmpu2ktd0ep/model.ckpt.
# INFO:tensorflow:Loss for final step: 72378.61.
# INFO:tensorflow:Restoring parameters from /tmp/tmpu2ktd0ep/model.ckpt-600
#   period 09 : 169.53
# Model training finished.
#         predictions       targets
# count  17000.000000  17000.000000
# mean     156.239685    207.300912
# std      128.834076    115.983764
# min        0.118270     14.999000
# 25%       86.403740    119.400000
# 50%      125.704994    180.400000
# 75%      186.237812    265.000000
# max     2242.062988    500.001000
# Final RMSE (on training data): 169.53
